# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthanadevisaminathan/pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
z=np.array([1,2,3,4,5])
type(z)
z
# Out:
# array([1, 2, 3, 4, 5])

# %%
s=pd.Series([10,22,11])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    10
# 1    22
# 2    11
# dtype: int64

# %%
s=pd.Series([10,22,11,55,66])
s.drop(2,inplace=True)
s
# Out:
# 0    10
# 1    22
# 3    55
# 4    66
# dtype: int64

# %%
s.iloc[1]
# Out:
# 22

# %%
a=12
b=pd.Series(a)
c = pd.concat([s,b],ignore_index=True)
c
# Out:
# 0    10
# 1    22
# 2    55
# 3    66
# 4    12
# dtype: int64

# %%
s.iloc[1]
# Out:
# 22

# %%
s.loc[1]
# Out:
# 22

# %%
a=pd.Series([1,2,3],index=['A','B','C'])
a
a.iloc[2]
# Out:
# 3

# %%
a.loc['C']
# Out:
# 3

# %%
data=[['ABC',10,'13-11-2003'],['DEF',12,None],['IGH',None,None]]
data
# Out:
# [['ABC', 10, '13-11-2003'], ['DEF', 12, None], ['IGH', None, None]]

# %%
df=pd.DataFrame(data)
df
# Out:
#      0     1           2
# 0  ABC  10.0  13-11-2003
# 1  DEF  12.0        None
# 2  IGH   NaN        None

# %%
df[0:1]
# Out:
#      0     1           2
# 0  ABC  10.0  13-11-2003

# %%
df[0][0]
# Out:
# 'ABC'

# %%
df[[0,2]]
# Out:
#      0           2
# 0  ABC  13-11-2003
# 1  DEF        None
# 2  IGH        None

# %%
df[1:2]
# Out:
#      0     1     2
# 1  DEF  12.0  None

# %%
df=pd.DataFrame(data,columns=['A','B','C'])
df
# Out:
#      A     B           C
# 0  ABC  10.0  13-11-2003
# 1  DEF  12.0        None
# 2  IGH   NaN        None

# %%
df['A'][1]
# Out:
# 'DEF'

# %%
df.loc[1]['A']
# Out:
# 'DEF'

# %%
df.loc[1,'A']
# Out:
# 'DEF'

# %%
s1=pd.Series([1,2,3])
s1.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=6)
# Out:
# <Axes: >

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
import numpy as
s2=s #s2=s.to_numpy()
type(s2)
# Out:
# numpy.ndarray

# %%
df.head(1)
# Out:
#      A     B           C
# 0  ABC  10.0  13-11-2003

# %%
df.tail(-1) #displays all rows in the DataFrame except the first row.
# Out:
#      A     B     C
# 1  DEF  12.0  None
# 2  IGH   NaN  None

# %%
df.tail(-2) #would show all rows in the DataFrame except the first two rows.
# Out:
#      A   B     C
# 2  IGH NaN  None

# %%
df
# Out:
#      A     B           C
# 0  ABC  10.0  13-11-2003
# 1  DEF  12.0        None
# 2  IGH   NaN        None

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False   True
# 2  False   True   True

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    2
# dtype: int64

# %%
df.notnull().sum()
# Out:
# A    3
# B    2
# C    1
# dtype: int64

# %%
df.dropna() #inplace=True - na df la null value irukara row mothama drop aairum
# Out:
#      A     B           C
# 0  ABC  10.0  13-11-2003

# %%
df
# Out:
#      A     B           C
# 0  ABC  10.0  13-11-2003
# 1  DEF  12.0        None
# 2  IGH   NaN        None

# %%
df.drop(['B'],axis=1)
# Out:
#      A           C
# 0  ABC  13-11-2003
# 1  DEF        None
# 2  IGH        None

# %%
df
# Out:
#      A     B           C
# 0  ABC  10.0  13-11-2003
# 1  DEF  12.0        None
# 2  IGH   NaN        None

# %%
df.drop([1],axis=0)
# Out:
#      A     B           C
# 0  ABC  10.0  13-11-2003
# 2  IGH   NaN        None

# %%
df.drop([0,2])
# Out:
#      A     B     C
# 1  DEF  12.0  None

# %%
s
# Out:
# array([10, 22, 55, 66])

# %%
s>10
# Out:
# array([False,  True,  True,  True])

# %%
s%2==0
# Out:
# array([ True,  True, False,  True])

# %%
z
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['A'].str.contains('D')
# Out:
# 0    False
# 1     True
# 2    False
# Name: A, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 3)
# 9
# [RangeIndex(start=0, stop=3, step=1), Index(['A', 'B', 'C'], dtype='object')]
# 2
# A     object
# B    float64
# C     object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['A', 'B', 'C'], dtype='object')
# [['ABC' 10.0 '13-11-2003']
#  ['DEF' 12.0 None]
#  ['IGH' nan None]]

# %%
df.describe(include='all')
# Out:
#           A          B           C
# count     3   2.000000           1
# unique    3        NaN           1
# top     ABC        NaN  13-11-2003
# freq      1        NaN           1
# mean    NaN  11.000000         NaN
# std     NaN   1.414214         NaN
# min     NaN  10.000000         NaN
# 25%     NaN  10.500000         NaN
# 50%     NaN  11.000000         NaN
# 75%     NaN  11.500000         NaN
# max     NaN  12.000000         NaN

# %%
df.describe()
# Out:
#                B
# count   2.000000
# mean   11.000000
# std     1.414214
# min    10.000000
# 25%    10.500000
# 50%    11.000000
# 75%    11.500000
# max    12.000000

# %%
df.describe(include='object')
# Out:
#           A           C
# count     3           1
# unique    3           1
# top     ABC  13-11-2003
# freq      1           1

# %%
import numpy as np
a=np.array([[1,2,3],[1,2,3]])
for i in a:
  a1=np.sum(i)
  print(a1)
# Out:
# 6
# 6

# %%
df.loc[0][0]
# Out:
# 'ABC'

# %%
df.loc[0,'A']
# Out:
# 'ABC'

# %%
df['A'][1]='13'
# Out:
# <ipython-input-121-f9f306b1f8e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['A'][1]='13'

# %%
df
# Out:
#      A     B           C
# 0  ABC  10.0  13-11-2003
# 1   13  12.0        None
# 2  IGH   NaN        None

# %%
import pandas as pd
f=pd.read_html('https://km.aifb.kit.edu/sites/webdatacommons/webtables/index.html')
print(f)
# Out:
# [  Unnamed: 0  min.    max.  average  median
# 0    columns     2   2 368     3.49       3
# 1       rows     1  70 068    12.41       6,                0          1              2        3            4        5   \
# 0       Countries  Countries         Cities   Cities       Rivers   Rivers
# 1            Name    #Tables           Name  #Tables         Name  #Tables
# 2             usa     135688       new york    59398  mississippi    87367
# 3         germany      91170     luxembourg    47722         lena     8717
# 4           japan      76512         berlin    46850          don     6504
# 5   united states      73169         london    37541    mackenzie     3346
# 6           italy      71129      amsterdam    31548      yangtze     2241
# 7         austria      56622         madrid    30486          oka     1708
# 8     netherlands      56533        andorra    21075        loire     1096
# 9          mexico      55267         dublin    19790       tigris      946
# ...

# %%
f=pd.DataFrame(f)
f.describe()
# Out:
#                                                         0
# count                                                   3
# unique                                                  3
# top       Unnamed: 0  min.    max.  average  median
# 0 ...
# freq                                                    1

# %%
type(f)
# Out:
# pandas.core.frame.DataFrame

# %%
g=pd.read_table('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv')
g
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
g.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
import numpy as np
f=np.array([[1,2,3],[1,2,3]])
for i in f:
  a=np.sum(i)
  print(a)
# Out:
# 6
# 6

# %%
g.item_price=g.item_price.str.replace('$','')
g.head(10)
# Out:
# <ipython-input-18-513ebcf0aae7>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   g.item_price=g.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
g.order_id=g.order_id.astype(float)
g.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0       1.0         1           Chips and Fresh Tomato Salsa
# 1       1.0         1                                   Izze
# 2       1.0         1                       Nantucket Nectar
# 3       1.0         1  Chips and Tomatillo-Green Chili Salsa
# 4       2.0         2                           Chicken Bowl
# 5       3.0         1                           Chicken Bowl
# 6       3.0         1                          Side of Chips
# 7       4.0         1                          Steak Burrito
# 8       4.0         1                       Steak Soft Tacos
# 9       5.0         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN         1.0
# 1                                       [Clementine]         1.0
# 2                                            [Apple]         1.0
# ...

# %%
g.order_id=g.order_id+100
g
# Out:
#       order_id  quantity                              item_name  \
# 0        400.0         1           Chips and Fresh Tomato Salsa
# 1        400.0         1                                   Izze
# 2        400.0         1                       Nantucket Nectar
# 3        400.0         1  Chips and Tomatillo-Green Chili Salsa
# 4        500.0         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617  183600.0         1                          Steak Burrito
# 4618  183600.0         1                          Steak Burrito
# 4619  183700.0         1                     Chicken Salad Bowl
# 4620  183700.0         1                     Chicken Salad Bowl
# 4621  183700.0         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN         1.0
# ...

# %%
g.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
g_drink=g[g.item_price < 1.1]
g_drink
# Out:
#    order_id  quantity                              item_name  \
# 0     400.0         1           Chips and Fresh Tomato Salsa
# 1     400.0         1                                   Izze
# 2     400.0         1                       Nantucket Nectar
# 3     400.0         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description  item_price
# 0                NaN         1.0
# 1       [Clementine]         1.0
# 2            [Apple]         1.0
# 3                NaN         1.0

# %%
g_drink.item_name.nunique()
# Out:
# 4

# %%
g_drink.item_name.value_counts()
# Out:
# Chips and Fresh Tomato Salsa             1
# Izze                                     1
# Nantucket Nectar                         1
# Chips and Tomatillo-Green Chili Salsa    1
# Name: item_name, dtype: int64

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv'
g = pd.read_table(url)
steak_burrito_df = g[g['item_name'] == 'Steak Burrito']
value_counts = steak_burrito_df['choice_description'].value_counts()
print(value_counts)
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
g[g.choice_description.str.contains('Black Beans',na=False)].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
g[(g.item_name=='Chicken Bowl')&(g.item_price<10)]
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %%
g
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN         NaN
# ...

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv'
g = pd.read_table(url)
g
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
g
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
g.item_price=g.item_price.astype(float)
g
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
g[(g.item_name=='Chicken Bowl')&(g.item_price<10)]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
h=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv')
h
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
h[(h.star_rating>9)&(h.content_rating=='R')]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
h[(h.star_rating>8)].sort_values(['duration'])
# Out:
#      star_rating                              title content_rating      genre  \
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# 283          8.1                      Before Sunset              R      Drama
# 117          8.3                          Toy Story              G  Animation
# ..           ...                                ...            ...        ...
# 204          8.1                            Ben-Hur              G  Adventure
# 85           8.4                 Lawrence of Arabia             PG  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
#
# ...

# %%
h[h.actors_list.str.contains('Charles Chaplin')].sort_values(['Star_rating']and['duration'])
# Out:
#      star_rating               title content_rating      genre  duration  \
# 88           8.4             The Kid      NOT RATED     Comedy        68
# 29           8.6         City Lights         PASSED     Comedy        87
# 35           8.6        Modern Times              G     Comedy        87
# 128          8.3       The Gold Rush      NOT RATED  Adventure        95
# 52           8.5  The Great Dictator       APPROVED     Comedy       125
#
#                                            actors_list
# 88   [u'Charles Chaplin', u'Edna Purviance', u'Jack...
# 29   [u'Charles Chaplin', u'Virginia Cherrill', u'F...
# 35   [u'Charles Chaplin', u'Paulette Goddard', u'He...
# 128  [u'Charles Chaplin', u'Mack Swain', u'Tom Murr...
# 52   [u'Charles Chaplin', u'Paulette Goddard', u'Ja...

# %%
h[h.actors_list.str.contains('Charles Chaplin')].sort_values(by=['star_rating','duration'],ascending=[True,False])
# Out:
#      star_rating               title content_rating      genre  duration  \
# 128          8.3       The Gold Rush      NOT RATED  Adventure        95
# 88           8.4             The Kid      NOT RATED     Comedy        68
# 52           8.5  The Great Dictator       APPROVED     Comedy       125
# 29           8.6         City Lights         PASSED     Comedy        87
# 35           8.6        Modern Times              G     Comedy        87
#
#                                            actors_list
# 128  [u'Charles Chaplin', u'Mack Swain', u'Tom Murr...
# 88   [u'Charles Chaplin', u'Edna Purviance', u'Jack...
# 52   [u'Charles Chaplin', u'Paulette Goddard', u'Ja...
# 29   [u'Charles Chaplin', u'Virginia Cherrill', u'F...
# 35   [u'Charles Chaplin', u'Paulette Goddard', u'He...

# %%
k=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv')
k.head(10)
# Out:
#                    City Colors Reported Shape Reported State              Time
# 0                Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ   6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS    6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY   4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND   9/15/1934 15:30
# 6           Crater Lake             NaN         CIRCLE    CA    6/15/1935 0:00
# 7                  Alma             NaN           DISK    MI    7/15/1936 0:00
# 8               Eklutna             NaN          CIGAR    AK  10/15/1936 17:00
# 9               Hubbard             NaN       CYLINDER    OR    6/15/1937 0:00

# %%
k.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
k['Shape Reported'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18236    False
# 18237    False
# 18238     True
# 18239    False
# 18240    False
# Name: Shape Reported, Length: 18241, dtype: bool

# %%
k['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
l=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv')
l.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# ...

# %%
l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
l.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
l['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
l[l.continent=='Asia']
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
l[l.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
l[l.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
l.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
l.groupby('continent').beer_servings.agg(['mean','max','min'])
# Out:
#                      mean  max  min
# continent
# Africa          61.471698  376    0
# Asia            37.045455  247    0
# Europe         193.777778  361    0
# North America  145.434783  285    1
# Oceania         89.687500  306    0
# South America  175.083333  333   93
